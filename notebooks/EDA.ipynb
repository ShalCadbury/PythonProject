# %%
import pandas as pd
import plotly plt
import streamlit as st

df = pd.read_csv(r"C:\Users\stanf\Documents\GitHub\PythonProject\vehicles_us.csv",parse_dates=['date_posted'], date_format='%Y-%m-%d')

df['model_year']=df['model_year'].astype('Int64')
df['odometer']=df['odometer'].astype('Int64')
df['odometer']=df['odometer'].fillna(0)
display(df.head())
#display(df.columns)
#display(df.info())
#display(df.describe())

st.header(" Car Advertisement Data")
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400        2011          bmw x5       good        6.0  gas    145000
# 1  25500        <NA>      ford f-150       good        6.0  gas     88705
# 2   5500        2013  hyundai sonata   like new        4.0  gas    110000
# 3   1500        2003      ford f-150       fair        8.0  gas         0
# 4  14900        2017    chrysler 200  excellent        4.0  gas     80903
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV         NaN     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     NaN  2019-02-07           79
# 3    automatic  pickup         NaN     NaN  2019-03-22            9
# 4    automatic   sedan       black     NaN  2019-04-02           28
# Index(['price', 'model_year', 'model', 'condition', 'cylinders', 'fuel',
# ...

# %%
import pandas as pd

import numpy as np

import streamlit as st


# Sample data

data = {'Study Hours': [2, 5, 3, 1, 4, 6, 2, 7, 8, 3],

        'Exam Score': [60, 80, 70, 50, 75, 90, 65, 95, 85, 70]}

df = pd.DataFrame(data)



# Display the scatter plot using st.write with a matplotlib figure

st.write("Scatter plot of Study Hours vs Exam Score:")

fig, ax = plt.subplots()

ax.scatter(df['Study Hours'], df['Exam Score'])

ax.set_xlabel('Study Hours')

ax.set_ylabel('Exam Score')

st.pyplot(fig)
# Out:
# 2025-02-20 23:44:08.724 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-20 23:44:10.612
# ...
#   command:
#
#     streamlit run C:\Users\stanf\AppData\Roaming\Python\Python39\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-02-20 23:44:10.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-20 23:44:10.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-20 23:44:10.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 22
#      18 # Display the scatter plot using st.write with a matplotlib figure
# ...

# %%
# Sample data (replace with your data source)
data = {'x': [1, 2, 3, 4, 5],
        'y': [2, 4, 1, 3, 5],
        'category': ['A', 'B', 'A', 'B', 'A']}
df = pd.DataFrame(data)

# Create the scatter plot using Plotly Express
fig = px.scatter(df, x='x', y='y', color='category',
                 title='Sample Scatter Plot')

# Display the plot in Streamlit
st.plotly_chart(fig)
# Out:
# 2025-02-21 21:29:48.912 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-21 21:29:48.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-21 21:29:48.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-21 21:29:48.954 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
